# %% [markdown]
# # Horizontal

# %%
 # x is y axis down
# y is x axis right

x1 = 11867
y1 = 9260

x2 = 17156
y2 = 11160

# %%
xDiff = x2 - x1
yDiff = y2 - y1

print("xDiff:", xDiff)
print("yDiff:", yDiff)
# Out:
# xDiff: 5289
# yDiff: 1900

# %%
first_code_x = 11000
first_code_y = 9050

one_down_y = first_code_y + yDiff
one_down_x = first_code_x

print("first_code_y:", first_code_y)
print("first_code_x:", first_code_x)
print("\n\none_down_y:", one_down_y)
print("one_down_x:", one_down_x)

one_right_x = first_code_x + xDiff
one_right_y = first_code_y

print("\n\none_right_y:", one_right_y)
print("one_right_x:", one_right_x)



# <g id="qr_code" transform="translate(xAxis: 11000, reversedY: 9050) scale(14)">
# first_code_x = 11000
# first_code_y = 9050
# xDiff: 5289
# yDiff: 1900
# Out:
# first_code_y: 9050
# first_code_x: 11000
#
#
# one_down_y: 10950
# one_down_x: 11000
#
#
# one_right_y: 9050
# one_right_x: 16289

# %%
# w poziomie 18
# w pionie 30
18 * 20
# Out:
# 360

# %%
''' FIRST CODE HORIZONTA
  <g id="qr_code" transform="translate(11000, 9050) scale(14)">
    <g transform="translate(320.0, 20.0)">
      <g fill="black">
      </g>
    </g>
    <text x="363.0" y="129.0" text-anchor="middle" font-family="Montserrat" font-size="20" font-weight="bold" fill="black">ID d3DQJ</text>
  </g>
  '''
# Out:
# ' FIRST CODE HORIZONTA\n  <g id="qr_code" transform="translate(11000, 9050) scale(14)">\n    <g transform="translate(320.0, 20.0)">\n      <g fill="black">\n      </g>\n    </g>\n    <text x="363.0" y="129.0" text-anchor="middle" font-family="Montserrat" font-size="20" font-weight="bold" fill="black">ID d3DQJ</text>\n  </g>\n  '

# %%
''' ONE DOWN
  <g id="qr_code" transform="translate(11000, 10950) scale(14)">
    <g transform="translate(320.0, 20.0)">
      <g fill="black">
      </g>
    </g>
    <text x="363.0" y="129.0" text-anchor="middle" font-family="Montserrat" font-size="20" font-weight="bold" fill="black">ID d3DQJ</text>
  </g>

'''
# Out:
# '\n  <g id="qr_code" transform="translate(11000, 10950) scale(14)">\n    <g transform="translate(320.0, 20.0)">\n      <g fill="black">\n      </g>\n    </g>\n    <text x="363.0" y="129.0" text-anchor="middle" font-family="Montserrat" font-size="20" font-weight="bold" fill="black">ID d3DQJ</text>\n  </g>\n\n'

# %%
''' ONE RIGHT
  <g id="qr_code" transform="translate(PRZESUNIECIE WZDŁOZ X W PRAWO, PRZESUNIECIE W DOL) scale(14)">
    <g transform="translate(320.0, 20.0)">
      <g fill="black">
      KOD TUTAJ
      </g>
    </g>
    <text x="363.0" y="129.0" text-anchor="middle" font-family="Montserrat" font-size="20" font-weight="bold" fill="black">ID d3DQJ</text>
  </g>
'''

# %% [markdown]
# # Vertical

# %%
# kolumn 30 - w poziomie 30 zawieszek
# wierszy 19 - w pionie 19 zawieszek

30 * 19
# Out:
# 570
