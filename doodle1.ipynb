# %%
C_0 = 1/(1.1)**2 * ((3/5)**2*79 + 2 *(3/5)*(2/5)*14)
print(C_0)
# Out:
# 29.057851239669414

# %%
P_0 = ((2/5)**2 * 26) / (1.1)**2
print(P_0)
# Out:
# 3.4380165289256204

# %%
P_01 = C_0 - 100+ (90)/(1.1**2)

# %%
print(P_01)
# Out:
# 3.4380165289256013
